# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('lastone.csv')

# %%
df.fillna(value = 4 , inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0       ID  year  Form No : (Sample Year/01)     Lable  \
# 0           0  2017_01  2017                           1  Positive
# 1           1  2017_02  2017                           2  Positive
# 2           2  2017_03  2017                           3  Positive
# 3           3  2017_04  2017                           4  Positive
# 4           4  2017_05  2017                           5  Positive
#
#    Q.1 The content was as described in publicity materials  \
# 0                                                4.0
# 1                                                5.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
#
#    Q.2 The workshop was applicable to my job  \
# 0                                          4
# 1                                          4
# 2                                          4
# 3                                          4
# ...

# %%
col = df.columns.to_frame()
col.set_index(np.arange(0,34), inplace= True)

# %%
col.iloc[5][0]
# Out:
# 'Q.1 The content was as described in publicity materials'

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'year', 'Form No : (Sample Year/01)', 'Lable',
#        'Q.1 The content was as described in publicity materials',
#        'Q.2 The workshop was applicable to my job',
#        'Q.3 I'll recommend this workshop to other conservators.',
#        'Q.4 The program was well paced within the allotted time',
#        'Q.5 The instructor was a good communicator ',
#        'Q.6 The material was presented in an organized manner',
#        'Q.7 The instructor was knowledgeable on topics ',
#        'Q.8 I'd be interested in tending a followup, more advanced workshop on the same subject',
#        'Q.9 Given the topic, was this workshop',
#        'Q.10 In your opinion, was this workshop',
#        'Q.11 Please Rate the following : Visual',
#        'Q.12 Please Rate the following : Acoustics',
#        'Q.13 Please Rate the following : Meeting Space',
#        'Q.14 Please Rate the following : Handouts',
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       ID  year  Form No : (Sample Year/01)     Lable  \
# 0           0  2017_01  2017                           1  Positive
# 1           1  2017_02  2017                           2  Positive
# 2           2  2017_03  2017                           3  Positive
# 3           3  2017_04  2017                           4  Positive
# 4           4  2017_05  2017                           5  Positive
#
#    Q.1 The content was as described in publicity materials  \
# 0                                                4.0
# 1                                                5.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
#
#    Q.2 The workshop was applicable to my job  \
# 0                                          4
# 1                                          4
# 2                                          4
# 3                                          4
# ...

# %%
A = []

# %%
for i in range(0 , 32):
    A.append(df[col.iloc[i][0]].value_counts().to_frame())

# %%
a = df[col.iloc[5][0]].value_counts().to_frame()
a.plot(kind = 'pie', y = col.iloc[5][0],autopct='%1.1f%%' , legend= False)

# %%
for i in range(0 , 32):
    A.append(df[col.iloc[i][0]].value_counts().to_frame())

# %%
for i in range(5 , 21):
    A[i].plot(kind = 'pie', y = col.iloc[i][0],autopct='%1.1f%%', legend= False)

# %%
sns.countplot(x =col.iloc[5][0]  , data = df , )

# %%
sns.countplot(x =col.iloc[6][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[7][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[8][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[9][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[10][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[11][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[12][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[13][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[14][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[15][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[16][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[17][0]  , data = df , hue = 'Lable')

# %%
sns.countplot(x =col.iloc[18][0]  , data = df , hue = 'Lable')

# %%
data = df[['Lable',
       'Q.1 The content was as described in publicity materials',    
       'Q.2 The workshop was applicable to my job',
       "Q.3 I'll recommend this workshop to other conservators.",
       'Q.4 The program was well paced within the allotted time',
       'Q.5 The instructor was a good communicator ',
       'Q.6 The material was presented in an organized manner',
       'Q.7 The instructor was knowledgeable on topics ',
       "Q.8 I'd be interested in tending a followup, more advanced workshop on the same subject",
       'Q.9 Given the topic, was this workshop',
       'Q.10 In your opinion, was this workshop',
       'Q.11 Please Rate the following : Visual',
       'Q.12 Please Rate the following : Acoustics',
       'Q.13 Please Rate the following : Meeting Space',
       'Q.14 Please Rate the following : Handouts',
       'Q.15 Please Rate the following : The program overall','score']]

# %%
data.head()
# Out:
#       Lable  Q.1 The content was as described in publicity materials  \
# 0  Positive                                                4.0
# 1  Positive                                                5.0
# 2  Positive                                                4.0
# 3  Positive                                                4.0
# 4  Positive                                                4.0
#
#    Q.2 The workshop was applicable to my job  \
# 0                                          4
# 1                                          4
# 2                                          4
# 3                                          4
# 4                                          4
#
#    Q.3 I'll recommend this workshop to other conservators.  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  4
# ...

# %%
from skleargn.cross_validation import train_test_split
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('Lable',axis=1), data['Lable'], test_size=0.33, random_state =101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-12227fe48456> in <module>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(data.drop('Lable',axis=1), data['Lable'], test_size=0.33, random_state =101)
#
# NameError: name 'data' is not defined

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()

# %%
model.fit(X_train , y_train)
# Out:
# GaussianNB(priors=None)

# %%
predicted= model.predict(X_test)

# %%
from sklearn.metrics import classification_report , confusion_matrix

# %%
print(confusion_matrix(y_test , predicted))
# Out:
# [[ 2  0]
#  [ 2 15]]

# %%
print(classification_report(y_test , predicted))
# Out:
#              precision    recall  f1-score   support
#
#    Negative       0.50      1.00      0.67         2
#    Positive       1.00      0.88      0.94        17
#
# avg / total       0.95      0.89      0.91        19
